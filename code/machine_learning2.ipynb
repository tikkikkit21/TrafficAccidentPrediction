# %% [markdown]
# # Machine Learning 2
# A different approach to ML models
#
# ## Import Packages & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate, train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, ConfusionMatrixDisplay
import itertools
import time

# %%
df = pd.read_csv('../data/us_accidents_expanded.csv')

# %% [markdown]
# ## Dataset Processing
# Before we can try out machine learning models, we need to first prepare our dataset.
# The first thing is to drop features that we don't believe are necessary.

# %%
df_ml = df.copy()

# dropping timestamps for now, relying on elapsed time instead
df_ml.drop(columns=['Start_Datetime', 'End_Datetime', 'Start_Date', 'End_Date', 'Start_Time', 'End_Time'], inplace=True)

# dropping exact coordinates, relying on distance instead
df_ml.drop(columns=['Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng'], inplace=True)

# description, address, weather timestamp, and airport don't provide any meaningful information
df_ml.drop(columns=['Description', 'Street', 'City', 'County', 'Zipcode', 'Weather_Timestamp', 'Airport_Code'], inplace=True)

# %% [markdown]
# Next we need to adjust the day/night features to true/false respectively.

# %%
# change day/night to true/false respectively
day_night = ['Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight']
df_ml[day_night] = df_ml[day_night].replace('Day', True)
df_ml[day_night] = df_ml[day_night].replace('Night', False)

# %% [markdown]
# We also need to drop records containing missing values. We've imputed what we can
# during the dataset processing, we now we just drop the remaining ones.

# %%
df_ml.dropna(inplace=True)

# %% [markdown]
# Finally, we need to convert the `Severity` target feature to string so it's
# treated as a discrete class value.

# %%
df_ml['Severity'] = df_ml['Severity'].astype(str)

# %% [markdown]
# We can now split into `X` (features) and `y` (target class) for training as well as
# dividing up the train/val/test sets.

# %%
X = df_ml.drop(columns=['Severity'])
y = df_ml['Severity']

# split off testing data
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.1, random_state=1234)

# split rest into training and validation
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=2/9, random_state=1234)

# %% [markdown]
# Before we start to train our models, we need to normalize our numerical data. We will
# use sklearn's `MinMaxScaler` for this.

# %%
scaler = MinMaxScaler()
numeric_columns = df_ml.select_dtypes(include=['number']).columns
print('Normalizing the following columns:')
for col in numeric_columns:
    print(f' - {col}')

X_train[numeric_columns] = scaler.fit_transform(X_train[numeric_columns])
X_val[numeric_columns] = scaler.transform(X_val[numeric_columns])
X_test[numeric_columns] = scaler.transform(X_test[numeric_columns])
# Out:
# Normalizing the following columns:
#  - Distance(mi)
#  - Temperature(F)
#  - Wind_Chill(F)
#  - Humidity(%)
#  - Pressure(in)
#  - Visibility(mi)
#  - Wind_Speed(mph)
#  - Precipitation(in)
#  - Elapsed_Hours

# %% [markdown]
# Our final processed dataset looks something like this:

# %%
X_train.head()
# Out:
#         Distance(mi)  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 214985      0.014837        0.395556       0.451613     0.683673
# 317281      0.006614        0.297778       0.350806     0.602041
# 105583      0.004035        0.524444       0.568548     0.581633
# 405621      0.000534        0.244444       0.266129     0.775510
# 484393      0.011163        0.328889       0.391129     0.479592
#
#         Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)  \
# 214985      0.919795           0.100         0.020576           0.000000
# 317281      0.878840           0.100         0.020576           0.000000
# 105583      0.912969           0.100         0.024691           0.000000
# 405621      0.883106           0.005         0.057613           0.000991
# 484393      0.805461           0.100         0.000000           0.000000
#
#         Amenity   Bump  ...  Region_West  Division_East North Central  \
# 214985    False  False  ...        False                        False
# 317281    False  False  ...        False                        False
# 105583    False  False  ...        False                        False
# 405621    False  False  ...        False                        False
# 484393    False  False  ...        False                        False
#
#         Division_East South Central  Division_Middle Atlantic  \
# 214985                        False                      True
# 317281                        False                     False
# 105583                        False                     False
# 405621                        False                      True
# 484393                        False                     False
#
#         Division_Mountain  Division_New England  Division_Pacific  \
# 214985              False                 False             False
# 317281              False                 False             False
# 105583              False                 False             False
# 405621              False                 False             False
# 484393              False                 False             False
#
#         Division_South Atlantic  Division_West North Central  \
# 214985                    False                        False
# 317281                    False                        False
# 105583                    False                        False
# 405621                    False                        False
# 484393                     True                        False
#
#         Division_West South Central
# 214985                        False
# 317281                         True
# 105583                         True
# 405621                        False
# 484393                        False
#
# [5 rows x 225 columns]

# %% [markdown]
# ## ML Models
# ### Logistic Regression

# %%
solvers = ['saga', 'sag', 'newton-cg']

best_lr_model = None
best_lr_solver = None
best_lr_acc = 0.0
lr_acc = []
lr_times = []

for solver in solvers:
    # set up logistic regressor
    logreg = LogisticRegression(
        solver=solver,
        random_state=1234,
        multi_class='multinomial',
        class_weight='balanced',
        max_iter=1000,
        n_jobs=-2
    )

    # train logistic regressor
    start_time = time.time()
    logreg.fit(X_train, y_train)
    acc = logreg.score(X_val, y_val)
    end_time = time.time()

    # get results
    print(f'Solver {solver} ({end_time - start_time:.1f}s): {acc}')
    lr_acc.append(acc)
    lr_times.append(end_time - start_time)

    # save best
    if acc > best_lr_acc:
        best_lr_model = logreg
        best_lr_acc = acc
        best_lr_solver = solver

print('=============')
print(f'Best logistic regressor solver is {best_lr_solver} with an accuracy of {best_lr_acc}')
# Out:
# c:\Users\Me\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Solver saga (1290.5s): 0.3532005975981153
# c:\Users\Me\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Solver sag (1187.0s): 0.16240016089180026
# Solver newton-cg (292.3s): 0.41764350973970005
# =============
# Best logistic regressor solver is newton-cg with an accuracy of 0.41764350973970005

# %%
fig, ax1 = plt.subplots()
ax1.plot(solvers, lr_acc, 'b-', label='Accuracy', marker='o')
ax1.set_xlabel('Solver')
ax1.set_ylabel('Accuracy')
ax2 = ax1.twinx()
ax2.plot(solvers, lr_times, 'r-', label='Time', marker='o')
ax2.set_ylabel('Training Time (s)')

plt.title('LogisticRegression Accuracies')
fig.legend(loc='upper right');

# %% [markdown]
# ### Decision Tree
# Next is a **Decision Tree** classifier.

# %%
criterion = ['gini', 'entropy']
max_depth = [10, 20, None]
min_samples_split = [2, 0.0001]
min_samples_leaf = [1, 5, 10]
max_features = [None, 'sqrt', 'log2']

dt_combos = list(itertools.product(criterion, max_depth, min_samples_split, min_samples_leaf, max_features))

best_dt_model = None
best_dt_param = None
best_dt_acc = 0.0
for combo in dt_combos:
    # set up tree model
    c, md, mss, msl, mf = combo
    tree = DecisionTreeClassifier(
        criterion=c,
        max_depth=md,
        min_samples_split=mss,
        min_samples_leaf=msl,
        max_features=mf,
        class_weight='balanced',
        random_state=1234
    )
    
    # train decision tree
    start_time = time.time()
    tree.fit(X_train, y_train)
    acc = tree.score(X_val, y_val)
    end_time = time.time()
    
    # get results
    print(f'Param {combo} ({end_time - start_time:.1f}s): {acc}')

    # save best
    if acc > best_dt_acc:
        best_dt_model = tree
        best_dt_acc = acc
        best_dt_param = combo

print('=============')
print(f'Best decision tree params are {best_dt_param} with an accuracy of {best_dt_acc}')
# Out:
# Param ('gini', 10, 2, 1, None) (5.2s): 0.48484456702867323
# Param ('gini', 10, 2, 1, 'sqrt') (1.4s): 0.3871889904039533
# Param ('gini', 10, 2, 1, 'log2') (1.3s): 0.34387749238637016
# Param ('gini', 10, 2, 5, None) (4.8s): 0.4834080330977418
# Param ('gini', 10, 2, 5, 'sqrt') (1.4s): 0.3590903867149342
# Param ('gini', 10, 2, 5, 'log2') (1.3s): 0.28319829914382577
# Param ('gini', 10, 2, 10, None) (4.6s): 0.48306326495431823
# Param ('gini', 10, 2, 10, 'sqrt') (1.4s): 0.28426133425271505
# Param ('gini', 10, 2, 10, 'log2') (1.3s): 0.20707636614376831
# Param ('gini', 10, 0.0001, 1, None) (4.6s): 0.48307763029362755
# Param ('gini', 10, 0.0001, 1, 'sqrt') (1.4s): 0.35469459288628397
# Param ('gini', 10, 0.0001, 1, 'log2') (1.3s): 0.13503418950755616
# Param ('gini', 10, 0.0001, 5, None) (5.5s): 0.48248865138194563
# Param ('gini', 10, 0.0001, 5, 'sqrt') (1.4s): 0.3645348503131644
# Param ('gini', 10, 0.0001, 5, 'log2') (1.2s): 0.2217433775785784
# Param ('gini', 10, 0.0001, 10, None) (4.6s): 0.4826035740964202
# Param ('gini', 10, 0.0001, 10, 'sqrt') (1.4s): 0.27844337183244267
# Param ('gini', 10, 0.0001, 10, 'log2') (1.3s): 0.21785037062575419
# Param ('gini', 20, 2, 1, None) (7.4s): 0.6145061196345458
# Param ('gini', 20, 2, 1, 'sqrt') (1.8s): 0.49673906797678563
# Param ('gini', 20, 2, 1, 'log2') (1.5s): 0.39980175831753145
# Param ('gini', 20, 2, 5, None) (7.3s): 0.5896397172901224
# Param ('gini', 20, 2, 5, 'sqrt') (2.1s): 0.47159972418548524
# Param ('gini', 20, 2, 5, 'log2') (1.9s): 0.402933402286962
# Param ('gini', 20, 2, 10, None) (8.0s): 0.5800436706315003
# Param ('gini', 20, 2, 10, 'sqrt') (1.9s): 0.41359248405447335
# Param ('gini', 20, 2, 10, 'log2') (1.5s): 0.38443084525656496
# Param ('gini', 20, 0.0001, 1, None) (7.3s): 0.5819398954203299
# Param ('gini', 20, 0.0001, 1, 'sqrt') (1.8s): 0.4909785669137505
# Param ('gini', 20, 0.0001, 1, 'log2') (1.5s): 0.3537033844739413
# Param ('gini', 20, 0.0001, 5, None) (7.1s): 0.576423605125553
# Param ('gini', 20, 0.0001, 5, 'sqrt') (1.7s): 0.4788685858759984
# Param ('gini', 20, 0.0001, 5, 'log2') (1.3s): 0.39542032982819053
# Param ('gini', 20, 0.0001, 10, None) (7.3s): 0.5754898580704476
# Param ('gini', 20, 0.0001, 10, 'sqrt') (1.8s): 0.44200712520829744
# Param ('gini', 20, 0.0001, 10, 'log2') (1.4s): 0.4689277710739528
# Param ('gini', None, 2, 1, None) (10.6s): 0.8004798023329311
# Param ('gini', None, 2, 1, 'sqrt') (2.4s): 0.7930960179279435
# Param ('gini', None, 2, 1, 'log2') (2.3s): 0.7895046831006148
# Param ('gini', None, 2, 5, None) (8.9s): 0.7141872091018789
# Param ('gini', None, 2, 5, 'sqrt') (2.0s): 0.5013359765557662
# Param ('gini', None, 2, 5, 'log2') (1.6s): 0.4608257197034994
# Param ('gini', None, 2, 10, None) (8.4s): 0.6727001091765787
# Param ('gini', None, 2, 10, 'sqrt') (1.8s): 0.46629891398034823
# Param ('gini', None, 2, 10, 'log2') (1.8s): 0.39343791300350517
# Param ('gini', None, 0.0001, 1, None) (9.3s): 0.7000517152215135
# Param ('gini', None, 0.0001, 1, 'sqrt') (2.1s): 0.583362064011952
# Param ('gini', None, 0.0001, 1, 'log2') (1.9s): 0.5800436706315003
# Param ('gini', None, 0.0001, 5, None) (9.1s): 0.6761046945928862
# Param ('gini', None, 0.0001, 5, 'sqrt') (2.3s): 0.5071108429581107
# Param ('gini', None, 0.0001, 5, 'log2') (1.7s): 0.4459001321611216
# Param ('gini', None, 0.0001, 10, None) (8.0s): 0.6625294489455841
# Param ('gini', None, 0.0001, 10, 'sqrt') (1.7s): 0.47803539619605817
# Param ('gini', None, 0.0001, 10, 'log2') (1.5s): 0.4366344883066138
# Param ('entropy', 10, 2, 1, None) (4.7s): 0.49003045451933575
# Param ('entropy', 10, 2, 1, 'sqrt') (1.4s): 0.3280325231281963
# Param ('entropy', 10, 2, 1, 'log2') (1.3s): 0.4142532896627018
# Param ('entropy', 10, 2, 5, None) (5.0s): 0.48889559271389993
# Param ('entropy', 10, 2, 5, 'sqrt') (1.5s): 0.35189335172096764
# Param ('entropy', 10, 2, 5, 'log2') (1.3s): 0.34226857438372693
# Param ('entropy', 10, 2, 10, None) (4.8s): 0.4885077285525484
# Param ('entropy', 10, 2, 10, 'sqrt') (1.4s): 0.4036229385738091
# Param ('entropy', 10, 2, 10, 'log2') (1.2s): 0.38352582888007813
# Param ('entropy', 10, 0.0001, 1, None) (4.7s): 0.48856518990978565
# Param ('entropy', 10, 0.0001, 1, 'sqrt') (1.4s): 0.3840717117738321
# Param ('entropy', 10, 0.0001, 1, 'log2') (1.3s): 0.25616273056369593
# Param ('entropy', 10, 0.0001, 5, None) (4.9s): 0.4884215365166925
# Param ('entropy', 10, 0.0001, 5, 'sqrt') (2.2s): 0.39273401137734876
# Param ('entropy', 10, 0.0001, 5, 'log2') (1.6s): 0.24492903522381199
# Param ('entropy', 10, 0.0001, 10, None) (5.0s): 0.48832097914152733
# Param ('entropy', 10, 0.0001, 10, 'sqrt') (1.4s): 0.27564213066712634
# Param ('entropy', 10, 0.0001, 10, 'log2') (1.4s): 0.2429466183991266
# Param ('entropy', 20, 2, 1, None) (7.9s): 0.6155260587255071
# Param ('entropy', 20, 2, 1, 'sqrt') (1.8s): 0.5243636154685973
# Param ('entropy', 20, 2, 1, 'log2') (1.5s): 0.4602511061311268
# Param ('entropy', 20, 2, 5, None) (7.5s): 0.5901281388266391
# Param ('entropy', 20, 2, 5, 'sqrt') (1.8s): 0.47047922771935874
# Param ('entropy', 20, 2, 5, 'log2') (1.4s): 0.4212204792277194
# Param ('entropy', 20, 2, 10, None) (7.3s): 0.5764523358041717
# Param ('entropy', 20, 2, 10, 'sqrt') (2.1s): 0.4333879216227087
# Param ('entropy', 20, 2, 10, 'log2') (1.5s): 0.435226685054301
# Param ('entropy', 20, 0.0001, 1, None) (7.4s): 0.5807044762397288
# Param ('entropy', 20, 0.0001, 1, 'sqrt') (1.8s): 0.4900017238407171
# Param ('entropy', 20, 0.0001, 1, 'log2') (1.5s): 0.4112365684077458
# Param ('entropy', 20, 0.0001, 5, None) (7.9s): 0.5745130149974143
# Param ('entropy', 20, 0.0001, 5, 'sqrt') (1.6s): 0.42461069930471756
# Param ('entropy', 20, 0.0001, 5, 'log2') (1.5s): 0.42143595931735905
# Param ('entropy', 20, 0.0001, 10, None) (8.6s): 0.5723725794403264
# Param ('entropy', 20, 0.0001, 10, 'sqrt') (2.1s): 0.4314055047980233
# Param ('entropy', 20, 0.0001, 10, 'log2') (1.4s): 0.4099580532092168
# Param ('entropy', None, 2, 1, None) (9.5s): 0.7945181865195656
# Param ('entropy', None, 2, 1, 'sqrt') (2.4s): 0.7921048095156008
# Param ('entropy', None, 2, 1, 'log2') (2.5s): 0.7876802850083319
# Param ('entropy', None, 2, 5, None) (8.7s): 0.7208096305234729
# Param ('entropy', None, 2, 5, 'sqrt') (2.0s): 0.5183014422800667
# Param ('entropy', None, 2, 5, 'log2') (1.5s): 0.45364305004884214
# Param ('entropy', None, 2, 10, None) (9.2s): 0.6767655002011147
# Param ('entropy', None, 2, 10, 'sqrt') (1.8s): 0.47553582715623743
# Param ('entropy', None, 2, 10, 'log2') (1.5s): 0.42377750962477734
# Param ('entropy', None, 0.0001, 1, None) (8.8s): 0.6972217433775786
# Param ('entropy', None, 0.0001, 1, 'sqrt') (2.2s): 0.5940929724760099
# Param ('entropy', None, 0.0001, 1, 'log2') (1.8s): 0.5765959891972648
# Param ('entropy', None, 0.0001, 5, None) (9.1s): 0.6797965867953801
# Param ('entropy', None, 0.0001, 5, 'sqrt') (1.8s): 0.47363960236740793
# Param ('entropy', None, 0.0001, 5, 'log2') (1.6s): 0.43972303625811643
# Param ('entropy', None, 0.0001, 10, None) (8.0s): 0.6668965120956157
# Param ('entropy', None, 0.0001, 10, 'sqrt') (1.8s): 0.4734384876170775
# Param ('entropy', None, 0.0001, 10, 'log2') (1.5s): 0.4342354766419583
# =============
# Best decision tree params are ('gini', None, 2, 1, None) with an accuracy of 0.8004798023329311

# %% [markdown]
# ### Neural Network

# %%
nn_sizes = {
    'A1': (20),
    'A2': (50),
    'A3': (100),
    'A4': (200),
    'A5': (50,50),
    'A6': (100,50),
    'A7': (100,100),
    'A8': (200,100),
    'A9': (100,100,100),
    'A10': (50,100,50),
    'A11': (100,100,50),
    'A12': (100,100,100),
    'A13': (100,150,100),
    'A14': (50, 100, 100, 50)
}

best_nn_model = None
best_nn_size = None
best_nn_acc = 0.0
nn_acc = []
nn_times = []

for case, size in nn_sizes.items():
    # set up MLP
    mlp = MLPClassifier(
        hidden_layer_sizes=size,
        alpha=0.01,
        random_state=1234,
        early_stopping=True,
    )

    # train MLP
    start_time = time.time()
    mlp.fit(X_train, y_train)
    acc = mlp.score(X_val, y_val)
    end_time = time.time()

    # get results
    print(f'{case} {size} ({end_time - start_time:.1f}s): {acc}')
    nn_acc.append(acc)
    nn_times.append(end_time - start_time)

    # save best
    if acc > best_nn_acc:
        best_nn_model = mlp
        best_nn_acc = acc
        best_nn_size = size

print('=============')
print(f'Best neural network design is {best_nn_size} with an accuracy of {best_nn_acc}')
# Out:
# A1 20 (11.0s): 0.8471958857668218
# A2 50 (35.7s): 0.8473970005171522
# A3 100 (27.1s): 0.8479141527322875
# A4 200 (53.7s): 0.8474113658564615
# A5 (50, 50) (79.0s): 0.8488191691087743
# A6 (100, 50) (38.0s): 0.8474257311957708
# A7 (100, 100) (36.0s): 0.848531862322588
# A8 (200, 100) (183.6s): 0.8499109348962822
# A9 (100, 100, 100) (333.6s): 0.850399356432799
# A10 (50, 100, 50) (463.4s): 0.8527983680974545
# A11 (100, 100, 50) (335.6s): 0.8516778716313279
# A12 (100, 100, 100) (331.2s): 0.850399356432799
# A13 (100, 150, 100) (236.9s): 0.8496954548066425
# A14 (50, 100, 100, 50) (331.3s): 0.8511176233982647
# =============
# Best neural network design is (50, 100, 50) with an accuracy of 0.8527983680974545

# %%
fig, ax1 = plt.subplots()
ax1.plot(nn_sizes.keys(), nn_acc, 'b-', label='Accuracy', marker='o')
ax1.set_xlabel('Architecture')
ax1.set_ylabel('Accuracy')
ax2 = ax1.twinx()
ax2.plot(nn_sizes.keys(), nn_times, 'r-', label='Time', marker='o')
ax2.set_ylabel('Training Time (s)')

plt.title('Neural Network Accuracies')
fig.legend(loc='upper right');

# %% [markdown]
# ### KNN

# %%
k_values = np.arange(1, 26, 2)

best_knn_model = None
best_k = 0
best_knn_acc = 0.0
knn_acc = []
knn_times = []

for k in k_values:
    # set up KNN
    knn = KNeighborsClassifier(
        n_neighbors=k,
        n_jobs=-2
    )

    # train KNN
    start_time = time.time()
    knn.fit(X_train, y_train)
    acc = knn.score(X_val, y_val)
    end_time = time.time()

    # get results
    print(f'K={k} ({end_time - start_time:.1f}s): {acc}')
    knn_acc.append(acc)
    knn_times.append(end_time - start_time)

    # save best
    if acc > best_knn_acc:
        best_knn_model = knn
        best_knn_acc = acc
        best_k = k

print('=============')
print(f'Best k-value is {best_k} with an accuracy of {best_knn_acc}')
# Out:
# K=1 (121.7s): 0.759955180141355
# K=3 (114.4s): 0.8135235304257886
# K=5 (102.1s): 0.8317818766879274
# K=7 (118.1s): 0.8379877032695512
# K=9 (115.3s): 0.8407027523990117
# K=11 (121.8s): 0.8425415158306039
# K=13 (132.2s): 0.8439924151008447
# K=15 (131.0s): 0.8447250474056197
# K=17 (126.9s): 0.8457162558179624
# K=19 (140.8s): 0.8463052347296444
# K=21 (128.6s): 0.8464057921048095
# K=23 (110.6s): 0.8466787335516864
# K=25 (106.1s): 0.846520714819284
# =============
# Best k-value is 23 with an accuracy of 0.8466787335516864

# %%
fig, ax1 = plt.subplots()
ax1.plot([str(k) for k in k_values], knn_acc, 'b-', label='Accuracy', marker='o')
ax1.set_xlabel('Architecture')
ax1.set_ylabel('Accuracy')
ax2 = ax1.twinx()
ax2.plot([str(k) for k in k_values], knn_times, 'r-', label='Time', marker='o')
ax2.set_ylabel('Training Time (s)')

plt.title('KNN Accuracies')
fig.legend(loc='upper right');

# %% [markdown]
# Elbow is at `k=7`

# %%
best_k=7
best_knn_model = KNeighborsClassifier(n_neighbors=best_k, n_jobs=-2)
best_knn_model.fit(X_train, y_train);

# %% [markdown]
# ## Comparison
# Before we choose the final model, we should evaluate the precision and recall
# for each model type.

# %%
display_labels=['Severity 1','Severity 2','Severity 3','Severity 4']

# %% [markdown]
# #### Logistic Regression

# %%
lr_pred = best_lr_model.predict(X_val)

# metrics
lr_precision = precision_score(y_val, lr_pred, average='macro')
lr_recall = recall_score(y_val, lr_pred, average='macro')
lr_f1 = f1_score(y_val, lr_pred, average='macro')
print(f'Precision: {lr_precision}')
print(f'Recall:    {lr_recall}')
print(f'F1:        {lr_f1}')

# confusion matrix
cm = confusion_matrix(y_val, lr_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('LogisticRegression Confusion Matrix');
# Out:
# Precision: 0.3199503830542954
# Recall:    0.5224492309090856
# F1:        0.2678269988127002

# %% [markdown]
# #### Decision Tree

# %%
dt_pred = best_dt_model.predict(X_val)

# metrics
dt_precision = precision_score(y_val, dt_pred, average='macro')
dt_recall = recall_score(y_val, dt_pred, average='macro')
dt_f1 = f1_score(y_val, dt_pred, average='macro')
print(f'Precision: {dt_precision}')
print(f'Recall:    {dt_recall}')
print(f'F1:        {dt_f1}')

# confusion matrix
cm = confusion_matrix(y_val, dt_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('Decision Tree Confusion Matrix');
# Out:
# Precision: 0.39703548712156206
# Recall:    0.40911287827908227
# F1:        0.40262230392865894

# %% [markdown]
# #### Neural Network

# %%
nn_pred = best_nn_model.predict(X_val)

# metrics
nn_precision = precision_score(y_val, nn_pred, average='macro')
nn_recall = recall_score(y_val, nn_pred, average='macro')
nn_f1 = f1_score(y_val, nn_pred, average='macro')
print(f'Precision: {nn_precision}')
print(f'Recall:    {nn_recall}')
print(f'F1:        {nn_f1}')

# confusion matrix
cm = confusion_matrix(y_val, nn_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title('Neural Network Confusion Matrix');
# Out:
# c:\Users\Me\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Precision: 0.4876894834250479
# Recall:    0.28573907259198716
# F1:        0.29262681210051267

# %% [markdown]
# #### KNN

# %%
knn_pred = best_knn_model.predict(X_val)

# metrics
knn_precision = precision_score(y_val, knn_pred, average='macro')
knn_recall = recall_score(y_val, knn_pred, average='macro')
knn_f1 = f1_score(y_val, knn_pred, average='macro')
print(f'Precision: {knn_precision}')
print(f'Recall:    {knn_recall}')
print(f'F1:        {knn_f1}')

# confusion matrix
cm = confusion_matrix(y_val, knn_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'KNN (k={best_k}) Confusion Matrix');
# Out:
# Precision: 0.3758269375079675
# Recall:    0.2724151429923829
# F1:        0.27395820300955637

# %% [markdown]
# ## Final Test Performance
# In the end, the best performing model was the decision tree. It had the best overall
# accuracy and F1 score. We can now run it on the test dataset and evaluate the performance.

# %%
final_acc = best_dt_model.score(X_test, y_test)
test_pred = best_dt_model.predict(X_test)

final_precision = precision_score(y_test, test_pred, average='macro')
final_recall = recall_score(y_test, test_pred, average='macro')
final_f1 = f1_score(y_test, test_pred, average='macro')
print(f'Acc: {final_acc}')
print(f'Precision: {final_precision}')
print(f'Recall:    {final_recall}')
print(f'F1:        {final_f1}')

cm = confusion_matrix(y_test, test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title(f'Final Decision Tree Confusion Matrix');
# Out:
# Acc: 0.801068781244613
# Precision: 0.3991928212473761
# Recall:    0.40704092299234035
# F1:        0.4027515513035673
